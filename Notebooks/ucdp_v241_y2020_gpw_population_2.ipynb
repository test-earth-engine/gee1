# %%
# @title code functions
import ee
import os
import io
import json
import geemap
import pandas as pd
import urllib.request

import seaborn

def json_to_pandas(data, columns):
  #json_io = io.StringIO(data)
  #df = pd.read_json(json_io)
  #df = pd.read_json(data)
  df = pd.DataFrame(data)
  print("df.shape:", df.shape )

  first_row = df.iloc[0]
  #print("first_row:", first_row)

  df = df[columns]
  print("columns:", print(df.columns))
  return df


def json_load_from_url(url):
  #url = "https://raw.githubusercontent.com/test-earth-engine/gee1/main/Jsons/ucdp_v241_y2020.json";
  output_file = "output.json"
  urllib.request.urlretrieve(url, output_file)
  print(f"File saved to: {output_file}")

  response = urllib.request.urlopen(url)
  data = response.read().decode()
  json_data = json.loads(data)
  #print(json_data)
  return json_data


def authentification_drive() :
  from google.colab import drive
  drive.mount('/content/drive')


def authentification_ee() :
  ## https://developers.google.com/earth-engine/guides/python_install
  service_account = "undp-test-earth-engine@undp-test-earth-engine.iam.gserviceaccount.com"
  try :
    credentials = ee.ServiceAccountCredentials(service_account, 'undp-test-earth-engine.json')
    ee.Initialize(credentials)
  except :
    ee.Authenticate()
    ee.Initialize(project="undp-test-earth-engine")

  print("[earth_tools]", ee.String('Earth Engine...').getInfo())

# %%
# @title code functions
def plot_geometry(geometry):
    m = geemap.Map(center=[0, 0], zoom=2)
    m.addLayer(geometry, {}, 'Geometry')
    m.addLayerControl()
    return m

def plot_geometries(geometries):
    m = geemap.Map(center=[0, 0], zoom=2)
    for k,v in geometries.items():
      m.addLayer(k, {}, v)
    m.addLayerControl()
    return m

def total_population_get(dataset, region_of_interest) :
  clipped_dataset = dataset.unmask(0).clip(region_of_interest)

  projection = dataset.projection(); #print(projection.nominalScale())

  total_population = clipped_dataset.reduceRegion(
      scale=projection.nominalScale(),
      reducer=ee.Reducer.sum(),
      geometry=region_of_interest,
      maxPixels=1e9
  )

  population_value = total_population.get('population_count')
  return population_value.getInfo(), clipped_dataset


def population_calculate(collection, region_of_interest):
  #collection = ee.ImageCollection('CIESIN/GPWv411/GPW_Population_Count')
  available_dates = collection.aggregate_array('system:time_start').map(lambda t: ee.Date(t).format('YYYY-MM-dd'))

  population = {}
  json_data = []
  for start_date in available_dates.getInfo() :
    subcollection = collection.filterDate(start_date, None)
    population_value, clipped_dataset = total_population_get(subcollection.first(), region_of_interest)
    #print(start_date, population_value )
    population[start_date] = population_value,clipped_dataset
    json_data.append({'start_date':start_date, 'population_value':population_value})

  return json_data


def total_population_test() :
  collection = ee.ImageCollection('CIESIN/GPWv411/GPW_Population_Count')
  collection_info = collection.getInfo()

  country_name = "Mexico"
  countries = ee.FeatureCollection("FAO/GAUL/2015/level0")
  country = countries.filter(ee.Filter.eq('ADM0_NAME', country_name))

  json_data = population_calculate(collection, country)
  print(json_data)
  assert(json_data[-1]["population_value"] == 140028589.62193522)

  lat,lon = 19.4326, -99.1332  # Mexico city
  region_of_interest = ee.Geometry.Point([lon,lat]).buffer(50000)
  json_data = population_calculate(collection, region_of_interest)
  print(json_data)
  assert(json_data[0]["population_value"] == 18894142.261089187)

#total_population_test()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# @title authentifications
authentification_ee()
authentification_drive()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [earth_tools] Earth Engine...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title total_population_test
# %%time
total_population_test()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [{'start_date': '2000-01-01', 'population_value': 95318311.04757665}, {'start_date': '2005-01-01', 'population_value': 102920410.05733086}, {'start_date': '2010-01-01', 'population_value': 111962007.6113942}, {'start_date': '2015-01-01', 'population_value': 123252080.51942815}, {'start_date': '2020-01-01', 'population_value': 140028589.62193522}]
# [{'start_date': '2000-01-01', 'population_value': 18894142.261089187}, {'start_date': '2005-01-01', 'population_value': 19634927.00906701}, {'start_date': '2010-01-01', 'population_value': 20565562.540432516}, {'start_date': '2015-01-01', 'population_value': 21753302.396740124}, {'start_date': '2020-01-01', 'population_value': 23301046.330478065}]
# CPU times: user 249 ms, sys: 21.4 ms, total: 271 ms
# Wall time: 31.9 s

# %%
# @title ucdp_v241_y2020
url = "https://raw.githubusercontent.com/test-earth-engine/gee1/main/Jsons/ucdp_v241_y2020.json";
data = json_load_from_url(url)

columns = ["latitude", "longitude", "date_start", "best", "id", "country"]
df = json_to_pandas(data, columns)
#print( df )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# File saved to: output.json
# df.shape: (13384, 49)
# Index(['latitude', 'longitude', 'date_start', 'best', 'id', 'country'], dtype='object')
# columns: None

# %%
grouped = df.groupby('country')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import matplotlib.pyplot as plt

def plot_best_by_country( data ):
    data = data.sort_values(ascending=False)
    data.plot(kind='bar')
    plt.yscale('log')
    plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sizes = grouped.size()
plot_best_by_country( sizes )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
bests = grouped['best'].sum()
plot_best_by_country( bests )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# @title Ukraine Test Population
# %%time

def colors_create(value):
  rgb_to_hex = lambda rgb : '#{:02x}{:02x}{:02x}'.format(rgb[0], rgb[1], rgb[2])

  color = plt.cm.RdYlBu(value)[:3]  # Get RGB color
  rgb = [int(c * 255) for c in color]  # Convert to 0-255 scale
  hex = rgb_to_hex(rgb)
  print(f"[colors_create] color({value}): '{rgb}' ({hex})")
  return hex



def population_total_calculate(collection, region_of_interest) :
  #collection = ee.ImageCollection('CIESIN/GPWv411/GPW_Population_Count')
  json_data = population_calculate(collection, region_of_interest)
  #print(json_data)
  return json_data


def create_merged_circle(coords, radius=50000): # 50 km
    circles = ee.FeatureCollection([
        ee.Feature(ee.Geometry.Point(coord).buffer(radius)) for coord in coords
    ])
    merge_geometries = lambda feature, merged : ee.Geometry(merged).union(feature.geometry())
    return ee.Geometry(circles.iterate(merge_geometries, ee.Geometry(circles.first().geometry())))


def get_unique_coords_by_country(key):
  group1 = grouped.get_group(key)
  #print( group1.iloc[0] )

  group_of_coords = group1.groupby(['longitude', 'latitude'])
  print(f"[get_unique_coords_by_country] country:'{key}'", "coords:", len(group_of_coords) )

  #for name2, group2 in group_of_coords:print(key, name2 , len(group2) )

  unique_coords = list(group_of_coords.groups.keys())
  print(f"List of keys: {len(unique_coords)}")
  return unique_coords


def population_total_by_country(collection, country) :
  coordinates = get_unique_coords_by_country(country)
  #assert( len(coordinates) == 55 )

  radius = 50 * 1000 # km -> m
  multiPolygon = create_merged_circle(coordinates, radius)
  print("type:", multiPolygon.getInfo()["type"]) # 'MultiPolygon'
  #assert( multiPolygon.getInfo()["type"] == 'MultiPolygon' )

  json_data = population_total_calculate(collection, multiPolygon)
  #assert(json_data[0]["population_value"] == 6958498.409845306) ## 'start_date': '2000-01-01'

  feature = ee.Feature(multiPolygon)
  feature = feature.set("population", json_data)

  df = pd.DataFrame(json_data)
  df["country"] = country
  return df, feature

country = "Ukraine"
collection = ee.ImageCollection('CIESIN/GPWv411/GPW_Population_Count')

populations,region_of_interest = population_total_by_country(collection, country)
print(populations)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [get_unique_coords_by_country] country:'Ukraine' coords: 55
# List of keys: 55
# type: MultiPolygon
#    start_date  population_value  country
# 0  2000-01-01      6.958498e+06  Ukraine
# 1  2005-01-01      6.652257e+06  Ukraine
# 2  2010-01-01      6.361832e+06  Ukraine
# 3  2015-01-01      6.086295e+06  Ukraine
# 4  2020-01-01      5.824780e+06  Ukraine
# CPU times: user 166 ms, sys: 8.19 ms, total: 174 ms
# Wall time: 8.35 s

# %%
plot_geometry(region_of_interest)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
populations['population_value'].plot(kind='barh', color=seaborn.palettes.mpl_palette('Dark2'))
#plt.xscale('log')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
feature = region_of_interest.set('color', '#FF0000')
geojson = feature.getInfo()
#print(geojson)

with open('geometry.geojson', 'w') as f:
    json.dump(geojson, f)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

geojson_file = 'geometry.geojson'
gdf = gpd.read_file(geojson_file)

gdf.plot()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# %%time
countries = list(grouped.groups.keys())
print(f"countries({len(countries)}): {countries}")

regions = {}
populations = {}
for i,country in enumerate(countries[::1]) :
  population, region = population_total_by_country(collection, country)
  regions[country] = region.set("country", country)
  populations[country] = population
  print(i, country, population)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# countries(62): ['Afghanistan', 'Algeria', 'Angola', 'Armenia', 'Austria', 'Azerbaijan', 'Bangladesh', 'Benin', 'Brazil', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Colombia', 'Congo', 'DR Congo (Zaire)', 'Egypt', 'Ethiopia', 'Guinea', 'Haiti', 'Honduras', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Ivory Coast', 'Kenya', 'Kingdom of eSwatini (Swaziland)', 'Lebanon', 'Liberia', 'Libya', 'Madagascar (Malagasy)', 'Mali', 'Mauritania', 'Mexico', 'Morocco', 'Mozambique', 'Myanmar (Burma)', 'Niger', 'Nigeria', 'Pakistan', 'Paraguay', 'Peru', 'Philippines', 'Russia (Soviet Union)', 'Saudi Arabia', 'Senegal', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Syria', 'Tanzania', 'Thailand', 'Tunisia', 'Turkey', 'Ukraine', 'Venezuela', 'Yemen (North Yemen)', 'Zimbabwe (Rhodesia)']
# [get_unique_coords_by_country] country:'Afghanistan' coords: 1159
# List of keys: 1159
# type: Polygon
# 0 Afghanistan    start_date  population_value      country
# 0  2000-01-01      2.636630e+07  Afghanistan
# 1  2005-01-01      2.895011e+07  Afghanistan
# 2  2010-01-01      3.198466e+07  Afghanistan
# 3  2015-01-01      3.552493e+07  Afghanistan
# 4  2020-01-01      3.963814e+07  Afghanistan
# [get_unique_coords_by_country] country:'Algeria' coords: 14
# List of keys: 14
# type: MultiPolygon
# 1 Algeria    start_date  population_value  country
# 0  2000-01-01      4.986110e+06  Algeria
# 1  2005-01-01      5.308792e+06  Algeria
# 2  2010-01-01      5.678474e+06  Algeria
# 3  2015-01-01      6.107711e+06  Algeria
# 4  2020-01-01      6.637068e+06  Algeria
# [get_unique_coords_by_country] country:'Angola' coords: 13
# List of keys: 13
# type: MultiPolygon
# 2 Angola    start_date  population_value country
# 0  2000-01-01      2.458948e+06  Angola
# 1  2005-01-01      3.168879e+06  Angola
# 2  2010-01-01      5.027755e+06  Angola
# 3  2015-01-01      9.335634e+06  Angola
# 4  2020-01-01      1.897019e+07  Angola
# [get_unique_coords_by_country] country:'Armenia' coords: 7
# List of keys: 7
# type: MultiPolygon
# 3 Armenia    start_date  population_value  country
# 0  2000-01-01      2.436089e+06  Armenia
# 1  2005-01-01      2.297298e+06  Armenia
# 2  2010-01-01      2.230193e+06  Armenia
# 3  2015-01-01      2.201600e+06  Armenia
# 4  2020-01-01      2.194839e+06  Armenia
# [get_unique_coords_by_country] country:'Austria' coords: 1
# List of keys: 1
# type: Polygon
# 4 Austria    start_date  population_value  country
# 0  2000-01-01      2.441949e+06  Austria
# 1  2005-01-01      2.554790e+06  Austria
# 2  2010-01-01      2.674238e+06  Austria
# 3  2015-01-01      2.800742e+06  Austria
# 4  2020-01-01      2.934790e+06  Austria
# [get_unique_coords_by_country] country:'Azerbaijan' coords: 46
# List of keys: 46
# type: Polygon
# 5 Azerbaijan    start_date  population_value     country
# 0  2000-01-01      4.326107e+06  Azerbaijan
# 1  2005-01-01      4.380648e+06  Azerbaijan
# 2  2010-01-01      4.462068e+06  Azerbaijan
# 3  2015-01-01      4.563992e+06  Azerbaijan
# 4  2020-01-01      4.682990e+06  Azerbaijan
# [get_unique_coords_by_country] country:'Bangladesh' coords: 4
# List of keys: 4
# type: MultiPolygon
# 6 Bangladesh    start_date  population_value     country
# 0  2000-01-01      2.752550e+07  Bangladesh
# 1  2005-01-01      3.112493e+07  Bangladesh
# 2  2010-01-01      3.533521e+07  Bangladesh
# 3  2015-01-01      4.027809e+07  Bangladesh
# 4  2020-01-01      4.610259e+07  Bangladesh
# [get_unique_coords_by_country] country:'Benin' coords: 1
# List of keys: 1
# type: Polygon
# 7 Benin    start_date  population_value country
# 0  2000-01-01     194606.350106   Benin
# 1  2005-01-01     235040.067764   Benin
# 2  2010-01-01     284238.493443   Benin
# 3  2015-01-01     344178.288436   Benin
# 4  2020-01-01     417298.044191   Benin
# [get_unique_coords_by_country] country:'Brazil' coords: 133
# List of keys: 133
# type: MultiPolygon
# 8 Brazil    start_date  population_value country
# 0  2000-01-01      5.895061e+07  Brazil
# 1  2005-01-01      6.234466e+07  Brazil
# 2  2010-01-01      6.604251e+07  Brazil
# 3  2015-01-01      7.008235e+07  Brazil
# 4  2020-01-01      7.450940e+07  Brazil
# [get_unique_coords_by_country] country:'Burkina Faso' coords: 118
# List of keys: 118
# type: MultiPolygon
# 9 Burkina Faso    start_date  population_value       country
# 0  2000-01-01      7.330747e+06  Burkina Faso
# 1  2005-01-01      8.710760e+06  Burkina Faso
# 2  2010-01-01      1.044210e+07  Burkina Faso
# 3  2015-01-01      1.263841e+07  Burkina Faso
# 4  2020-01-01      1.545710e+07  Burkina Faso
# [get_unique_coords_by_country] country:'Burundi' coords: 62
# List of keys: 62
# type: Polygon
# 10 Burundi    start_date  population_value  country
# 0  2000-01-01      1.040944e+07  Burundi
# 1  2005-01-01      1.180114e+07  Burundi
# 2  2010-01-01      1.349301e+07  Burundi
# 3  2015-01-01      1.555909e+07  Burundi
# 4  2020-01-01      1.809826e+07  Burundi
# [get_unique_coords_by_country] country:'Cameroon' coords: 144
# List of keys: 144
# type: MultiPolygon
# 11 Cameroon    start_date  population_value   country
# 0  2000-01-01      1.031187e+07  Cameroon
# 1  2005-01-01      1.184328e+07  Cameroon
# 2  2010-01-01      1.364910e+07  Cameroon
# 3  2015-01-01      1.578290e+07  Cameroon
# 4  2020-01-01      1.830947e+07  Cameroon
# [get_unique_coords_by_country] country:'Central African Republic' coords: 34
# List of keys: 34
# type: MultiPolygon
# 12 Central African Republic    start_date  population_value                   country
# 0  2000-01-01      2.280591e+06  Central African Republic
# 1  2005-01-01      2.548909e+06  Central African Republic
# 2  2010-01-01      2.851111e+06  Central African Republic
# 3  2015-01-01      3.191873e+06  Central African Republic
# 4  2020-01-01      3.576585e+06  Central African Republic
# [get_unique_coords_by_country] country:'Chad' coords: 15
# List of keys: 15
# type: MultiPolygon
# 13 Chad    start_date  population_value country
# 0  2000-01-01      6.144812e+05    Chad
# 1  2005-01-01      7.356213e+05    Chad
# 2  2010-01-01      8.819702e+05    Chad
# 3  2015-01-01      1.059209e+06    Chad
# 4  2020-01-01      1.274444e+06    Chad
# [get_unique_coords_by_country] country:'Colombia' coords: 80
# List of keys: 80
# type: MultiPolygon
# 14 Colombia    start_date  population_value   country
# 0  2000-01-01      2.008816e+07  Colombia
# 1  2005-01-01      2.266081e+07  Colombia
# 2  2010-01-01      2.575627e+07  Colombia
# 3  2015-01-01      2.955804e+07  Colombia
# 4  2020-01-01      3.439059e+07  Colombia
# [get_unique_coords_by_country] country:'Congo' coords: 1
# List of keys: 1
# type: Polygon
# 15 Congo    start_date  population_value country
# 0  2000-01-01      1.053162e+06   Congo
# 1  2005-01-01      8.601152e+05   Congo
# 2  2010-01-01      7.360993e+05   Congo
# 3  2015-01-01      6.876225e+05   Congo
# 4  2020-01-01      7.373353e+05   Congo
# [get_unique_coords_by_country] country:'DR Congo (Zaire)' coords: 539
# List of keys: 539
# type: MultiPolygon
# 16 DR Congo (Zaire)    start_date  population_value           country
# 0  2000-01-01      2.753260e+07  DR Congo (Zaire)
# 1  2005-01-01      3.195800e+07  DR Congo (Zaire)
# 2  2010-01-01      3.762436e+07  DR Congo (Zaire)
# 3  2015-01-01      4.493131e+07  DR Congo (Zaire)
# 4  2020-01-01      5.449860e+07  DR Congo (Zaire)
# [get_unique_coords_by_country] country:'Egypt' coords: 32
# List of keys: 32
# type: MultiPolygon
# 17 Egypt    start_date  population_value country
# 0  2000-01-01      2.087363e+07   Egypt
# 1  2005-01-01      2.279447e+07   Egypt
# 2  2010-01-01      2.516875e+07   Egypt
# 3  2015-01-01      2.824406e+07   Egypt
# 4  2020-01-01      3.248838e+07   Egypt
# [get_unique_coords_by_country] country:'Ethiopia' coords: 171
# List of keys: 171
# type: MultiPolygon
# 18 Ethiopia    start_date  population_value   country
# 0  2000-01-01      3.184100e+07  Ethiopia
# 1  2005-01-01      3.636477e+07  Ethiopia
# 2  2010-01-01      4.154869e+07  Ethiopia
# 3  2015-01-01      4.749146e+07  Ethiopia
# 4  2020-01-01      5.430683e+07  Ethiopia
# [get_unique_coords_by_country] country:'Guinea' coords: 3
# List of keys: 3
# type: Polygon
# 19 Guinea    start_date  population_value country
# 0  2000-01-01      8.423059e+05  Guinea
# 1  2005-01-01      8.735118e+05  Guinea
# 2  2010-01-01      9.115741e+05  Guinea
# 3  2015-01-01      9.571493e+05  Guinea
# 4  2020-01-01      1.011030e+06  Guinea
# [get_unique_coords_by_country] country:'Haiti' coords: 3
# List of keys: 3
# type: Polygon
# 20 Haiti    start_date  population_value country
# 0  2000-01-01      3.351144e+06   Haiti
# 1  2005-01-01      3.797202e+06   Haiti
# 2  2010-01-01      4.407379e+06   Haiti
# 3  2015-01-01      5.226679e+06   Haiti
# 4  2020-01-01      6.327330e+06   Haiti
# [get_unique_coords_by_country] country:'Honduras' coords: 1
# List of keys: 1
# type: Polygon
# 21 Honduras    start_date  population_value   country
# 0  2000-01-01      1.224344e+06  Honduras
# 1  2005-01-01      1.362162e+06  Honduras
# 2  2010-01-01      1.516801e+06  Honduras
# 3  2015-01-01      1.690493e+06  Honduras
# 4  2020-01-01      1.885798e+06  Honduras
# [get_unique_coords_by_country] country:'India' coords: 239
# List of keys: 239
# type: MultiPolygon
# 22 India    start_date  population_value country
# 0  2000-01-01      1.608356e+08   India
# 1  2005-01-01      1.764194e+08   India
# 2  2010-01-01      1.938955e+08   India
# 3  2015-01-01      2.135223e+08   India
# 4  2020-01-01      2.355997e+08   India
# [get_unique_coords_by_country] country:'Indonesia' coords: 11
# List of keys: 11
# type: MultiPolygon
# 23 Indonesia    start_date  population_value    country
# 0  2000-01-01      3.415993e+05  Indonesia
# 1  2005-01-01      5.161180e+05  Indonesia
# 2  2010-01-01      8.022098e+05  Indonesia
# 3  2015-01-01      1.284794e+06  Indonesia
# 4  2020-01-01      2.121936e+06  Indonesia
# [get_unique_coords_by_country] country:'Iran' coords: 25
# List of keys: 25
# type: MultiPolygon
# 24 Iran    start_date  population_value country
# 0  2000-01-01      2.143028e+07    Iran
# 1  2005-01-01      1.981880e+07    Iran
# 2  2010-01-01      1.984769e+07    Iran
# 3  2015-01-01      2.058757e+07    Iran
# 4  2020-01-01      2.170761e+07    Iran
# [get_unique_coords_by_country] country:'Iraq' coords: 120
# List of keys: 120
# type: MultiPolygon
# 25 Iraq    start_date  population_value country
# 0  2000-01-01      1.994640e+07    Iraq
# 1  2005-01-01      2.292437e+07    Iraq
# 2  2010-01-01      2.644459e+07    Iraq
# 3  2015-01-01      3.063019e+07    Iraq
# 4  2020-01-01      3.563973e+07    Iraq
# [get_unique_coords_by_country] country:'Israel' coords: 5
# List of keys: 5
# type: Polygon
# 26 Israel    start_date  population_value country
# 0  2000-01-01      8.830592e+06  Israel
# 1  2005-01-01      9.877922e+06  Israel
# 2  2010-01-01      1.106408e+07  Israel
# 3  2015-01-01      1.240854e+07  Israel
# 4  2020-01-01      1.393360e+07  Israel
# [get_unique_coords_by_country] country:'Ivory Coast' coords: 1
# List of keys: 1
# type: Polygon
# 27 Ivory Coast    start_date  population_value      country
# 0  2000-01-01     604086.968652  Ivory Coast
# 1  2005-01-01     642276.110061  Ivory Coast
# 2  2010-01-01     684604.275800  Ivory Coast
# 3  2015-01-01     731622.673420  Ivory Coast
# 4  2020-01-01     783964.617944  Ivory Coast
# [get_unique_coords_by_country] country:'Kenya' coords: 49
# List of keys: 49
# type: MultiPolygon
# 28 Kenya    start_date  population_value country
# 0  2000-01-01      1.779440e+07   Kenya
# 1  2005-01-01      2.075830e+07   Kenya
# 2  2010-01-01      2.435166e+07   Kenya
# 3  2015-01-01      2.876230e+07   Kenya
# 4  2020-01-01      3.425450e+07   Kenya
# [get_unique_coords_by_country] country:'Kingdom of eSwatini (Swaziland)' coords: 2
# List of keys: 2
# type: Polygon
# 29 Kingdom of eSwatini (Swaziland)    start_date  population_value                          country
# 0  2000-01-01     760152.280957  Kingdom of eSwatini (Swaziland)
# 1  2005-01-01     784639.012684  Kingdom of eSwatini (Swaziland)
# 2  2010-01-01     810332.667414  Kingdom of eSwatini (Swaziland)
# 3  2015-01-01     837292.389192  Kingdom of eSwatini (Swaziland)
# 4  2020-01-01     865580.443438  Kingdom of eSwatini (Swaziland)
# [get_unique_coords_by_country] country:'Lebanon' coords: 3
# List of keys: 3
# type: Polygon
# 30 Lebanon    start_date  population_value  country
# 0  2000-01-01      3.548797e+06  Lebanon
# 1  2005-01-01      4.119403e+06  Lebanon
# 2  2010-01-01      4.824111e+06  Lebanon
# 3  2015-01-01      5.699439e+06  Lebanon
# 4  2020-01-01      6.793664e+06  Lebanon
# [get_unique_coords_by_country] country:'Liberia' coords: 2
# List of keys: 2
# type: MultiPolygon
# 31 Liberia    start_date  population_value  country
# 0  2000-01-01      1.308018e+06  Liberia
# 1  2005-01-01      1.488121e+06  Liberia
# 2  2010-01-01      1.699807e+06  Liberia
# 3  2015-01-01      1.948692e+06  Liberia
# 4  2020-01-01      2.241429e+06  Liberia
# [get_unique_coords_by_country] country:'Libya' coords: 28
# List of keys: 28
# type: MultiPolygon
# 32 Libya    start_date  population_value country
# 0  2000-01-01      2.462282e+06   Libya
# 1  2005-01-01      2.650224e+06   Libya
# 2  2010-01-01      2.852513e+06   Libya
# 3  2015-01-01      3.070244e+06   Libya
# 4  2020-01-01      3.304596e+06   Libya
# [get_unique_coords_by_country] country:'Madagascar (Malagasy)' coords: 1
# List of keys: 1
# type: Polygon
# 33 Madagascar (Malagasy)    start_date  population_value                country
# 0  2000-01-01     318575.806959  Madagascar (Malagasy)
# 1  2005-01-01     400193.870320  Madagascar (Malagasy)
# 2  2010-01-01     504011.966005  Madagascar (Malagasy)
# 3  2015-01-01     636288.024401  Madagascar (Malagasy)
# 4  2020-01-01     805081.124198  Madagascar (Malagasy)
# [get_unique_coords_by_country] country:'Mali' coords: 133
# List of keys: 133
# type: MultiPolygon
# 34 Mali    start_date  population_value country
# 0  2000-01-01      4.481351e+06    Mali
# 1  2005-01-01      5.254176e+06    Mali
# 2  2010-01-01      6.209777e+06    Mali
# 3  2015-01-01      7.406062e+06    Mali
# 4  2020-01-01      8.930203e+06    Mali
# [get_unique_coords_by_country] country:'Mauritania' coords: 1
# List of keys: 1
# type: Polygon
# 35 Mauritania    start_date  population_value     country
# 0  2000-01-01     234131.068958  Mauritania
# 1  2005-01-01     263198.572229  Mauritania
# 2  2010-01-01     296455.865386  Mauritania
# 3  2015-01-01     334562.662039  Mauritania
# 4  2020-01-01     378296.935284  Mauritania
# [get_unique_coords_by_country] country:'Mexico' coords: 445
# List of keys: 445
# type: MultiPolygon
# 36 Mexico    start_date  population_value country
# 0  2000-01-01      8.308522e+07  Mexico
# 1  2005-01-01      8.963449e+07  Mexico
# 2  2010-01-01      9.743262e+07  Mexico
# 3  2015-01-01      1.072241e+08  Mexico
# 4  2020-01-01      1.221466e+08  Mexico
# [get_unique_coords_by_country] country:'Morocco' coords: 1
# List of keys: 1
# type: Polygon
# 37 Morocco    start_date  population_value  country
# 0  2000-01-01        187.014977  Morocco
# 1  2005-01-01        188.860388  Morocco
# 2  2010-01-01        192.266843  Morocco
# 3  2015-01-01        197.335461  Morocco
# 4  2020-01-01        204.189754  Morocco
# [get_unique_coords_by_country] country:'Mozambique' coords: 108
# List of keys: 108
# type: MultiPolygon
# 38 Mozambique    start_date  population_value     country
# 0  2000-01-01      1.304124e+06  Mozambique
# 1  2005-01-01      1.430351e+06  Mozambique
# 2  2010-01-01      1.578248e+06  Mozambique
# 3  2015-01-01      1.753308e+06  Mozambique
# 4  2020-01-01      1.962991e+06  Mozambique
# [get_unique_coords_by_country] country:'Myanmar (Burma)' coords: 38
# List of keys: 38
# type: MultiPolygon
# 39 Myanmar (Burma)    start_date  population_value          country
# 0  2000-01-01      6.473315e+06  Myanmar (Burma)
# 1  2005-01-01      6.374159e+06  Myanmar (Burma)
# 2  2010-01-01      6.346236e+06  Myanmar (Burma)
# 3  2015-01-01      6.387609e+06  Myanmar (Burma)
# 4  2020-01-01      6.497444e+06  Myanmar (Burma)
# [get_unique_coords_by_country] country:'Niger' coords: 48
# List of keys: 48
# type: MultiPolygon
# 40 Niger    start_date  population_value country
# 0  2000-01-01      3.065402e+06   Niger
# 1  2005-01-01      3.618239e+06   Niger
# 2  2010-01-01      4.284563e+06   Niger
# 3  2015-01-01      5.093145e+06   Niger
# 4  2020-01-01      6.082762e+06   Niger
# [get_unique_coords_by_country] country:'Nigeria' coords: 306
# List of keys: 306
# type: MultiPolygon
# 41 Nigeria    start_date  population_value  country
# 0  2000-01-01      7.215888e+07  Nigeria
# 1  2005-01-01      8.394918e+07  Nigeria
# 2  2010-01-01      9.768233e+07  Nigeria
# 3  2015-01-01      1.136832e+08  Nigeria
# 4  2020-01-01      1.323330e+08  Nigeria
# [get_unique_coords_by_country] country:'Pakistan' coords: 105
# List of keys: 105
# type: MultiPolygon
# 42 Pakistan    start_date  population_value   country
# 0  2000-01-01      5.717321e+07  Pakistan
# 1  2005-01-01      6.449529e+07  Pakistan
# 2  2010-01-01      7.280319e+07  Pakistan
# 3  2015-01-01      8.223570e+07  Pakistan
# 4  2020-01-01      9.295220e+07  Pakistan
# [get_unique_coords_by_country] country:'Paraguay' coords: 1
# List of keys: 1
# type: Polygon
# 43 Paraguay    start_date  population_value   country
# 0  2000-01-01     130224.500907  Paraguay
# 1  2005-01-01     144934.739093  Paraguay
# 2  2010-01-01     161362.191474  Paraguay
# 3  2015-01-01     179712.250223  Paraguay
# 4  2020-01-01     200215.354354  Paraguay
# [get_unique_coords_by_country] country:'Peru' coords: 3
# List of keys: 3
# type: MultiPolygon
# 44 Peru    start_date  population_value country
# 0  2000-01-01     295602.472788    Peru
# 1  2005-01-01     312228.906762    Peru
# 2  2010-01-01     332583.453023    Peru
# 3  2015-01-01     357576.348530    Peru
# 4  2020-01-01     388396.139972    Peru
# [get_unique_coords_by_country] country:'Philippines' coords: 140
# List of keys: 140
# type: MultiPolygon
# 45 Philippines    start_date  population_value      country
# 0  2000-01-01      6.536069e+07  Philippines
# 1  2005-01-01      6.857556e+07  Philippines
# 2  2010-01-01      7.333052e+07  Philippines
# 3  2015-01-01      7.957018e+07  Philippines
# 4  2020-01-01      8.739292e+07  Philippines
# [get_unique_coords_by_country] country:'Russia (Soviet Union)' coords: 17
# List of keys: 17
# type: MultiPolygon
# 46 Russia (Soviet Union)    start_date  population_value                country
# 0  2000-01-01      8.694422e+06  Russia (Soviet Union)
# 1  2005-01-01      8.677796e+06  Russia (Soviet Union)
# 2  2010-01-01      8.680115e+06  Russia (Soviet Union)
# 3  2015-01-01      8.701941e+06  Russia (Soviet Union)
# 4  2020-01-01      8.743955e+06  Russia (Soviet Union)
# [get_unique_coords_by_country] country:'Saudi Arabia' coords: 1
# List of keys: 1
# type: Polygon
# 47 Saudi Arabia    start_date  population_value       country
# 0  2000-01-01      7.987261e+05  Saudi Arabia
# 1  2005-01-01      9.584246e+05  Saudi Arabia
# 2  2010-01-01      1.150053e+06  Saudi Arabia
# 3  2015-01-01      1.379997e+06  Saudi Arabia
# 4  2020-01-01      1.655915e+06  Saudi Arabia
# [get_unique_coords_by_country] country:'Senegal' coords: 1
# List of keys: 1
# type: Polygon
# 48 Senegal    start_date  population_value  country
# 0  2000-01-01     400966.715108  Senegal
# 1  2005-01-01     456755.411518  Senegal
# 2  2010-01-01     520720.476854  Senegal
# 3  2015-01-01     594088.563607  Senegal
# 4  2020-01-01     678272.437516  Senegal
# [get_unique_coords_by_country] country:'Somalia' coords: 140
# List of keys: 140
# type: MultiPolygon
# 49 Somalia    start_date  population_value  country
# 0  2000-01-01      4.484407e+06  Somalia
# 1  2005-01-01      5.195513e+06  Somalia
# 2  2010-01-01      6.055227e+06  Somalia
# 3  2015-01-01      7.111772e+06  Somalia
# 4  2020-01-01      8.435257e+06  Somalia
# [get_unique_coords_by_country] country:'South Africa' coords: 7
# List of keys: 7
# type: MultiPolygon
# 50 South Africa    start_date  population_value       country
# 0  2000-01-01      1.443475e+07  South Africa
# 1  2005-01-01      1.609801e+07  South Africa
# 2  2010-01-01      1.800100e+07  South Africa
# 3  2015-01-01      2.017953e+07  South Africa
# 4  2020-01-01      2.267503e+07  South Africa
# [get_unique_coords_by_country] country:'South Sudan' coords: 44
# List of keys: 44
# type: MultiPolygon
# 51 South Sudan    start_date  population_value      country
# 0  2000-01-01      3.216883e+06  South Sudan
# 1  2005-01-01      3.759501e+06  South Sudan
# 2  2010-01-01      4.461221e+06  South Sudan
# 3  2015-01-01      5.400565e+06  South Sudan
# 4  2020-01-01      6.727043e+06  South Sudan
# [get_unique_coords_by_country] country:'Sudan' coords: 52
# List of keys: 52
# type: MultiPolygon
# 52 Sudan    start_date  population_value country
# 0  2000-01-01      7.136740e+06   Sudan
# 1  2005-01-01      8.190245e+06   Sudan
# 2  2010-01-01      9.448638e+06   Sudan
# 3  2015-01-01      1.095452e+07   Sudan
# 4  2020-01-01      1.275983e+07   Sudan
# [get_unique_coords_by_country] country:'Syria' coords: 481
# List of keys: 481
# type: MultiPolygon
# 53 Syria    start_date  population_value country
# 0  2000-01-01      2.238308e+07   Syria
# 1  2005-01-01      2.533130e+07   Syria
# 2  2010-01-01      2.875203e+07   Syria
# 3  2015-01-01      3.273642e+07   Syria
# 4  2020-01-01      3.739956e+07   Syria
# [get_unique_coords_by_country] country:'Tanzania' coords: 13
# List of keys: 13
# type: MultiPolygon
# 54 Tanzania    start_date  population_value   country
# 0  2000-01-01      2.733543e+06  Tanzania
# 1  2005-01-01      3.063366e+06  Tanzania
# 2  2010-01-01      3.444967e+06  Tanzania
# 3  2015-01-01      3.887910e+06  Tanzania
# 4  2020-01-01      4.403704e+06  Tanzania
# [get_unique_coords_by_country] country:'Thailand' coords: 25
# List of keys: 25
# type: Polygon
# 55 Thailand    start_date  population_value   country
# 0  2000-01-01      3.257211e+06  Thailand
# 1  2005-01-01      3.401439e+06  Thailand
# 2  2010-01-01      3.556059e+06  Thailand
# 3  2015-01-01      3.721906e+06  Thailand
# 4  2020-01-01      3.899884e+06  Thailand
# [get_unique_coords_by_country] country:'Tunisia' coords: 4
# List of keys: 4
# type: MultiPolygon
# 56 Tunisia    start_date  population_value  country
# 0  2000-01-01      4.185009e+06  Tunisia
# 1  2005-01-01      4.501366e+06  Tunisia
# 2  2010-01-01      4.863246e+06  Tunisia
# 3  2015-01-01      5.278503e+06  Tunisia
# 4  2020-01-01      5.756720e+06  Tunisia
# [get_unique_coords_by_country] country:'Turkey' coords: 47
# List of keys: 47
# type: MultiPolygon
# 57 Turkey    start_date  population_value country
# 0  2000-01-01      1.100398e+07  Turkey
# 1  2005-01-01      1.132039e+07  Turkey
# 2  2010-01-01      1.191590e+07  Turkey
# 3  2015-01-01      1.278476e+07  Turkey
# 4  2020-01-01      1.396491e+07  Turkey
# [get_unique_coords_by_country] country:'Ukraine' coords: 55
# List of keys: 55
# type: MultiPolygon
# 58 Ukraine    start_date  population_value  country
# 0  2000-01-01      6.958498e+06  Ukraine
# 1  2005-01-01      6.652257e+06  Ukraine
# 2  2010-01-01      6.361832e+06  Ukraine
# 3  2015-01-01      6.086295e+06  Ukraine
# 4  2020-01-01      5.824780e+06  Ukraine
# [get_unique_coords_by_country] country:'Venezuela' coords: 4
# List of keys: 4
# type: MultiPolygon
# 59 Venezuela    start_date  population_value    country
# 0  2000-01-01      7.185794e+06  Venezuela
# 1  2005-01-01      7.678208e+06  Venezuela
# 2  2010-01-01      8.221970e+06  Venezuela
# 3  2015-01-01      8.824245e+06  Venezuela
# 4  2020-01-01      9.493867e+06  Venezuela
# [get_unique_coords_by_country] country:'Yemen (North Yemen)' coords: 268
# List of keys: 268
# type: MultiPolygon
# 60 Yemen (North Yemen)    start_date  population_value              country
# 0  2000-01-01      1.681367e+07  Yemen (North Yemen)
# 1  2005-01-01      1.927657e+07  Yemen (North Yemen)
# 2  2010-01-01      2.210129e+07  Yemen (North Yemen)
# 3  2015-01-01      2.534117e+07  Yemen (North Yemen)
# 4  2020-01-01      2.905745e+07  Yemen (North Yemen)
# [get_unique_coords_by_country] country:'Zimbabwe (Rhodesia)' coords: 1
# List of keys: 1
# type: Polygon
# 61 Zimbabwe (Rhodesia)    start_date  population_value              country
# 0  2000-01-01     154565.057464  Zimbabwe (Rhodesia)
# 1  2005-01-01     175175.515817  Zimbabwe (Rhodesia)
# 2  2010-01-01     199188.634568  Zimbabwe (Rhodesia)
# 3  2015-01-01     227207.825926  Zimbabwe (Rhodesia)
# 4  2020-01-01     259949.040665  Zimbabwe (Rhodesia)
# CPU times: user 12.9 s, sys: 526 ms, total: 13.5 s
# Wall time: 7min 7s

# %%
def population_to_colors( populations ):
  populations_values = {}
  for key,values in populations.items():
    populations_values[key] = values['population_value'][0] / 1e6

  populations_values = pd.DataFrame(list(populations_values.items()), columns=['Country', 'Value'])

  min_value = populations_values['Value'].min()
  populations_values['Value'] = populations_values['Value'] - min_value

  max_value = populations_values['Value'].max()
  populations_values['Value'] = populations_values['Value'] / max_value


  populations_values = populations_values.set_index('Country')['Value'].to_dict()
  print(populations_values)

  colors = {}
  for key,value in populations_values.items():
    colors[key] = {"hex":colors_create(value), "value":value}

  #print(colors)
  return colors

colors = population_to_colors( populations )
print(colors)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'Afghanistan': 0.1639322533910146, 'Algeria': 0.03100015486201785, 'Angola': 0.01528743497031637, 'Armenia': 0.015145310230671028, 'Austria': 0.015181744534155411, 'Azerbaijan': 0.02689655975143522, 'Bangladesh': 0.17113963822727846, 'Benin': 0.001208809149674718, 'Brazil': 0.3665263584417549, 'Burkina Faso': 0.04557801577740762, 'Burundi': 0.06471991549307939, 'Cameroon': 0.0641132483124731, 'Central African Republic': 0.014178494574419217, 'Chad': 0.0038193961575951614, 'Colombia': 0.12489770031459224, 'Congo': 0.0065469091504362, 'DR Congo (Zaire)': 0.17118373571116344, 'Egypt': 0.12978136009806668, 'Ethiopia': 0.19797139922382437, 'Guinea': 0.005235904484087051, 'Haiti': 0.02083469261276774, 'Honduras': 0.007611240486566161, 'India': 1.0, 'Indonesia': 0.0021227431596284444, 'Iran': 0.1332423897398424, 'Iraq': 0.12401628834235809, 'Israel': 0.05490335984213241, 'Ivory Coast': 0.0037547694986613204, 'Kenya': 0.11063618384707709, 'Kingdom of eSwatini (Swaziland)': 0.004725111143625417, 'Lebanon': 0.02206361157942286, 'Liberia': 0.008131482808061745, 'Libya': 0.015308161055967297, 'Madagascar (Malagasy)': 0.0019795936687426346, 'Mali': 0.027861797478253913, 'Mauritania': 0.0014545554986961562, 'Mexico': 0.516584185421618, 'Morocco': 0.0, 'Mozambique': 0.00810727513596499, 'Myanmar (Burma)': 0.04024690717085019, 'Niger': 0.0190580817537515, 'Nigeria': 0.4486492581053726, 'Pakistan': 0.35547529578996545, 'Paraguay': 0.0008085127062535826, 'Peru': 0.0018367561442431376, 'Philippines': 0.40638126075573705, 'Russia (Soviet Union)': 0.054056717631712325, 'Saudi Arabia': 0.004964945457753146, 'Senegal': 0.0024918620784385847, 'Somalia': 0.027880799012451104, 'South Africa': 0.0897473841905918, 'South Sudan': 0.01999991900531345, 'Sudan': 0.04437177186845326, 'Syria': 0.13916645723766913, 'Tanzania': 0.016994741128878315, 'Thailand': 0.020250660034355408, 'Tunisia': 0.026019278077549786, 'Turkey': 0.06841647863476115, 'Ukraine': 0.043263549249618005, 'Venezuela': 0.04467676958956267, 'Yemen (North Yemen)': 0.10453843960450371, 'Zimbabwe (Rhodesia)': 0.0009598509846973261}
# [colors_create] color(0.1639322533910146): '[232, 85, 56]' (#e85538)
# [colors_create] color(0.03100015486201785): '[178, 13, 38]' (#b20d26)
# [colors_create] color(0.01528743497031637): '[170, 5, 38]' (#aa0526)
# [colors_create] color(0.015145310230671028): '[170, 5, 38]' (#aa0526)
# [colors_create] color(0.015181744534155411): '[170, 5, 38]' (#aa0526)
# [colors_create] color(0.02689655975143522): '[176, 11, 38]' (#b00b26)
# [colors_create] color(0.17113963822727846): '[234, 89, 58]' (#ea593a)
# [colors_create] color(0.001208809149674718): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.3665263584417549): '[253, 206, 127]' (#fdce7f)
# [colors_create] color(0.04557801577740762): '[186, 20, 38]' (#ba1426)
# [colors_create] color(0.06471991549307939): '[196, 30, 38]' (#c41e26)
# [colors_create] color(0.0641132483124731): '[196, 30, 38]' (#c41e26)
# [colors_create] color(0.014178494574419217): '[170, 5, 38]' (#aa0526)
# [colors_create] color(0.0038193961575951614): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.12489770031459224): '[221, 61, 45]' (#dd3d2d)
# [colors_create] color(0.0065469091504362): '[166, 1, 38]' (#a60126)
# [colors_create] color(0.17118373571116344): '[234, 89, 58]' (#ea593a)
# [colors_create] color(0.12978136009806668): '[223, 65, 47]' (#df412f)
# [colors_create] color(0.19797139922382437): '[242, 106, 65]' (#f26a41)
# [colors_create] color(0.005235904484087051): '[166, 1, 38]' (#a60126)
# [colors_create] color(0.02083469261276774): '[174, 9, 38]' (#ae0926)
# [colors_create] color(0.007611240486566161): '[166, 1, 38]' (#a60126)
# [colors_create] color(1.0): '[49, 54, 149]' (#313695)
# [colors_create] color(0.0021227431596284444): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.1332423897398424): '[224, 68, 48]' (#e04430)
# [colors_create] color(0.12401628834235809): '[221, 61, 45]' (#dd3d2d)
# [colors_create] color(0.05490335984213241): '[192, 26, 38]' (#c01a26)
# [colors_create] color(0.0037547694986613204): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.11063618384707709): '[217, 53, 41]' (#d93529)
# [colors_create] color(0.004725111143625417): '[166, 1, 38]' (#a60126)
# [colors_create] color(0.02206361157942286): '[174, 9, 38]' (#ae0926)
# [colors_create] color(0.008131482808061745): '[168, 3, 38]' (#a80326)
# [colors_create] color(0.015308161055967297): '[170, 5, 38]' (#aa0526)
# [colors_create] color(0.0019795936687426346): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.027861797478253913): '[178, 13, 38]' (#b20d26)
# [colors_create] color(0.0014545554986961562): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.516584185421618): '[249, 252, 201]' (#f9fcc9)
# [colors_create] color(0.0): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.00810727513596499): '[168, 3, 38]' (#a80326)
# [colors_create] color(0.04024690717085019): '[184, 18, 38]' (#b81226)
# [colors_create] color(0.0190580817537515): '[172, 7, 38]' (#ac0726)
# [colors_create] color(0.4486492581053726): '[254, 238, 166]' (#feeea6)
# [colors_create] color(0.35547529578996545): '[253, 202, 123]' (#fdca7b)
# [colors_create] color(0.0008085127062535826): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.0018367561442431376): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.40638126075573705): '[254, 226, 147]' (#fee293)
# [colors_create] color(0.054056717631712325): '[190, 24, 38]' (#be1826)
# [colors_create] color(0.004964945457753146): '[166, 1, 38]' (#a60126)
# [colors_create] color(0.0024918620784385847): '[165, 0, 38]' (#a50026)
# [colors_create] color(0.027880799012451104): '[178, 13, 38]' (#b20d26)
# [colors_create] color(0.0897473841905918): '[208, 41, 38]' (#d02926)
# [colors_create] color(0.01999991900531345): '[174, 9, 38]' (#ae0926)
# [colors_create] color(0.04437177186845326): '[186, 20, 38]' (#ba1426)
# [colors_create] color(0.13916645723766913): '[225, 70, 49]' (#e14631)
# [colors_create] color(0.016994741128878315): '[172, 7, 38]' (#ac0726)
# [colors_create] color(0.020250660034355408): '[174, 9, 38]' (#ae0926)
# [colors_create] color(0.026019278077549786): '[176, 11, 38]' (#b00b26)
# [colors_create] color(0.06841647863476115): '[198, 32, 38]' (#c62026)
# [colors_create] color(0.043263549249618005): '[186, 20, 38]' (#ba1426)
# [colors_create] color(0.04467676958956267): '[186, 20, 38]' (#ba1426)
# [colors_create] color(0.10453843960450371): '[215, 49, 39]' (#d73127)
# [colors_create] color(0.0009598509846973261): '[165, 0, 38]' (#a50026)
# {'Afghanistan': {'hex': '#e85538', 'value': 0.1639322533910146}, 'Algeria': {'hex': '#b20d26', 'value': 0.03100015486201785}, 'Angola': {'hex': '#aa0526', 'value': 0.01528743497031637}, 'Armenia': {'hex': '#aa0526', 'value': 0.015145310230671028}, 'Austria': {'hex': '#aa0526', 'value': 0.015181744534155411}, 'Azerbaijan': {'hex': '#b00b26', 'value': 0.02689655975143522}, 'Bangladesh': {'hex': '#ea593a', 'value': 0.17113963822727846}, 'Benin': {'hex': '#a50026', 'value': 0.001208809149674718}, 'Brazil': {'hex': '#fdce7f', 'value': 0.3665263584417549}, 'Burkina Faso': {'hex': '#ba1426', 'value': 0.04557801577740762}, 'Burundi': {'hex': '#c41e26', 'value': 0.06471991549307939}, 'Cameroon': {'hex': '#c41e26', 'value': 0.0641132483124731}, 'Central African Republic': {'hex': '#aa0526', 'value': 0.014178494574419217}, 'Chad': {'hex': '#a50026', 'value': 0.0038193961575951614}, 'Colombia': {'hex': '#dd3d2d', 'value': 0.12489770031459224}, 'Congo': {'hex': '#a60126', 'value': 0.0065469091504362}, 'DR Congo (Zaire)': {'hex': '#ea593a', 'value': 0.17118373571116344}, 'Egypt': {'hex': '#df412f', 'value': 0.12978136009806668}, 'Ethiopia': {'hex': '#f26a41', 'value': 0.19797139922382437}, 'Guinea': {'hex': '#a60126', 'value': 0.005235904484087051}, 'Haiti': {'hex': '#ae0926', 'value': 0.02083469261276774}, 'Honduras': {'hex': '#a60126', 'value': 0.007611240486566161}, 'India': {'hex': '#313695', 'value': 1.0}, 'Indonesia': {'hex': '#a50026', 'value': 0.0021227431596284444}, 'Iran': {'hex': '#e04430', 'value': 0.1332423897398424}, 'Iraq': {'hex': '#dd3d2d', 'value': 0.12401628834235809}, 'Israel': {'hex': '#c01a26', 'value': 0.05490335984213241}, 'Ivory Coast': {'hex': '#a50026', 'value': 0.0037547694986613204}, 'Kenya': {'hex': '#d93529', 'value': 0.11063618384707709}, 'Kingdom of eSwatini (Swaziland)': {'hex': '#a60126', 'value': 0.004725111143625417}, 'Lebanon': {'hex': '#ae0926', 'value': 0.02206361157942286}, 'Liberia': {'hex': '#a80326', 'value': 0.008131482808061745}, 'Libya': {'hex': '#aa0526', 'value': 0.015308161055967297}, 'Madagascar (Malagasy)': {'hex': '#a50026', 'value': 0.0019795936687426346}, 'Mali': {'hex': '#b20d26', 'value': 0.027861797478253913}, 'Mauritania': {'hex': '#a50026', 'value': 0.0014545554986961562}, 'Mexico': {'hex': '#f9fcc9', 'value': 0.516584185421618}, 'Morocco': {'hex': '#a50026', 'value': 0.0}, 'Mozambique': {'hex': '#a80326', 'value': 0.00810727513596499}, 'Myanmar (Burma)': {'hex': '#b81226', 'value': 0.04024690717085019}, 'Niger': {'hex': '#ac0726', 'value': 0.0190580817537515}, 'Nigeria': {'hex': '#feeea6', 'value': 0.4486492581053726}, 'Pakistan': {'hex': '#fdca7b', 'value': 0.35547529578996545}, 'Paraguay': {'hex': '#a50026', 'value': 0.0008085127062535826}, 'Peru': {'hex': '#a50026', 'value': 0.0018367561442431376}, 'Philippines': {'hex': '#fee293', 'value': 0.40638126075573705}, 'Russia (Soviet Union)': {'hex': '#be1826', 'value': 0.054056717631712325}, 'Saudi Arabia': {'hex': '#a60126', 'value': 0.004964945457753146}, 'Senegal': {'hex': '#a50026', 'value': 0.0024918620784385847}, 'Somalia': {'hex': '#b20d26', 'value': 0.027880799012451104}, 'South Africa': {'hex': '#d02926', 'value': 0.0897473841905918}, 'South Sudan': {'hex': '#ae0926', 'value': 0.01999991900531345}, 'Sudan': {'hex': '#ba1426', 'value': 0.04437177186845326}, 'Syria': {'hex': '#e14631', 'value': 0.13916645723766913}, 'Tanzania': {'hex': '#ac0726', 'value': 0.016994741128878315}, 'Thailand': {'hex': '#ae0926', 'value': 0.020250660034355408}, 'Tunisia': {'hex': '#b00b26', 'value': 0.026019278077549786}, 'Turkey': {'hex': '#c62026', 'value': 0.06841647863476115}, 'Ukraine': {'hex': '#ba1426', 'value': 0.043263549249618005}, 'Venezuela': {'hex': '#ba1426', 'value': 0.04467676958956267}, 'Yemen (North Yemen)': {'hex': '#d73127', 'value': 0.10453843960450371}, 'Zimbabwe (Rhodesia)': {'hex': '#a50026', 'value': 0.0009598509846973261}}

# %%
# %%time

features = []
for country,region in regions.items() :
  color = colors.get(country)
  features.append(region.set("color", color))

features = ee.FeatureCollection(features)
geojson = features.getInfo()
#print(geojson)

geojson_file = 'regions.geojson'
with open(geojson_file, 'w') as f: json.dump(geojson, f)

import geopandas as gpd
import matplotlib.pyplot as plt

gdf = gpd.read_file(geojson_file)

gdf.plot()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# CPU times: user 2.57 s, sys: 176 ms, total: 2.74 s
# Wall time: 21.3 s

# %%
messages = []
for key,values in populations.items():
  message = f"{key} : "
  values = values.to_dict(orient='records')
  message += f"{values[0]['population_value'] / 1e6:.2f}"
  messages.append(message)

print( messages )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['Afghanistan : 26.37', 'Algeria : 4.99', 'Angola : 2.46', 'Armenia : 2.44', 'Austria : 2.44', 'Azerbaijan : 4.33', 'Bangladesh : 27.53', 'Benin : 0.19', 'Brazil : 58.95', 'Burkina Faso : 7.33', 'Burundi : 10.41', 'Cameroon : 10.31', 'Central African Republic : 2.28', 'Chad : 0.61', 'Colombia : 20.09', 'Congo : 1.05', 'DR Congo (Zaire) : 27.53', 'Egypt : 20.87', 'Ethiopia : 31.84', 'Guinea : 0.84', 'Haiti : 3.35', 'Honduras : 1.22', 'India : 160.84', 'Indonesia : 0.34', 'Iran : 21.43', 'Iraq : 19.95', 'Israel : 8.83', 'Ivory Coast : 0.60', 'Kenya : 17.79', 'Kingdom of eSwatini (Swaziland) : 0.76', 'Lebanon : 3.55', 'Liberia : 1.31', 'Libya : 2.46', 'Madagascar (Malagasy) : 0.32', 'Mali : 4.48', 'Mauritania : 0.23', 'Mexico : 83.09', 'Morocco : 0.00', 'Mozambique : 1.30', 'Myanmar (Burma) : 6.47', 'Niger : 3.07', 'Nigeria : 72.16', 'Pakistan : 57.17', 'Paraguay : 0.13', 'Peru : 0.30', 'Philippines : 65.36', 'Russia (Soviet Union) : 8.69', 'Saudi Arabia : 0.80', 'Senegal : 0.40', 'Somalia : 4.48', 'South Africa : 14.43', 'South Sudan : 3.22', 'Sudan : 7.14', 'Syria : 22.38', 'Tanzania : 2.73', 'Thailand : 3.26', 'Tunisia : 4.19', 'Turkey : 11.00', 'Ukraine : 6.96', 'Venezuela : 7.19', 'Yemen (North Yemen) : 16.81', 'Zimbabwe (Rhodesia) : 0.15']

# %%
# @title widgets
import ipywidgets
import ipyleaflet
import ipywidgets as widgets

def message_create(map, message, position) :
  text = f"""
  <div style="
      font-size:14px;
      color:white;
      background-color:black;
      padding: 5px;
      border-radius: 5px;
      opacity: 0.8;
  ">
  {message}
  </div>
  """
  text_widget = ipywidgets.HTML(value=text)
  text_control = ipyleaflet.WidgetControl(widget=text_widget, position=position)
  map.add_control(text_control)


def list_create(map, items, position):
    message = "Show / Hide Population list"

    # Toggle button (styled as plain text)
    toggle_button = ipywidgets.Button(
        description=message,
        layout=ipywidgets.Layout(width='auto'), #, background_color='black'),
        style=dict(button_color='white', font_color='black')
    )


    list_widget = widgets.HTML(
        value=f"<ul>{''.join(f'<li>{item}</li>' for item in items)}</ul>",
        layout=widgets.Layout(height='100px', overflow_y='auto', padding='5px', display='none')
    )

    # Toggle function
    def toggle_list(_):
        list_widget.layout.display = 'block' if list_widget.layout.display == 'none' else 'none'

    # Attach toggle event to button
    toggle_button.on_click(toggle_list)

    # Add widgets to map
    container = widgets.VBox([toggle_button, list_widget])
    map.add_control(ipyleaflet.WidgetControl(widget=container, position=position))


def test() :
  items =  ["Item %d" % i for i in range(100)]
  #items = messages
  map = geemap.Map(center=(20, 0), zoom=2)
  list_create(map, items, 'bottomleft')
  message_create(map, "By SpicyTech", 'topleft')
  return map

test()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(child…

# %%
# %%time
import geemap
import folium
import matplotlib.pyplot as plt

def plot_geometries(geometries, colors) :
    m = geemap.Map(center=[0, 0], zoom=2)

    for name,geometry in geometries.items():
      #m.addLayer(geometry, {}, name)
      color = colors.get(name, 0)
      m.addLayer(geometry, {'color': str(color)}, name)
    #m.addLayerControl()
    return m

def map_plot(regions, values) :
  map = plot_geometries(regions, values)
  list_create(map, messages, 'bottomleft')
  message_create(map, "By SpicyTech", 'topleft')
  map.save("map.html")
  return map

import itertools
print("n_regions:", len(regions) )
sub_regions = dict( itertools.islice(regions.items(),0,None,1) )
print( sub_regions.keys() )

def rgb_to_hex(rgb):
    return '#{:02x}{:02x}{:02x}'.format(rgb[0], rgb[1], rgb[2])

colors = {}
for s in sub_regions.keys() :
  value = populations_values[s]
  color = plt.cm.RdYlBu(value)[:3]  # Get RGB color
  color = [int(c * 255) for c in color]  # Convert to 0-255 scale
  #print(s, value, color)
  colors[s] = rgb_to_hex(color)

map_plot(sub_regions, colors)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# n_regions: 62
# dict_keys(['Afghanistan', 'Algeria', 'Angola', 'Armenia', 'Austria', 'Azerbaijan', 'Bangladesh', 'Benin', 'Brazil', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Colombia', 'Congo', 'DR Congo (Zaire)', 'Egypt', 'Ethiopia', 'Guinea', 'Haiti', 'Honduras', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Ivory Coast', 'Kenya', 'Kingdom of eSwatini (Swaziland)', 'Lebanon', 'Liberia', 'Libya', 'Madagascar (Malagasy)', 'Mali', 'Mauritania', 'Mexico', 'Morocco', 'Mozambique', 'Myanmar (Burma)', 'Niger', 'Nigeria', 'Pakistan', 'Paraguay', 'Peru', 'Philippines', 'Russia (Soviet Union)', 'Saudi Arabia', 'Senegal', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Syria', 'Tanzania', 'Thailand', 'Tunisia', 'Turkey', 'Ukraine', 'Venezuela', 'Yemen (North Yemen)', 'Zimbabwe (Rhodesia)'])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'populations_values' is not defined

# %%
json_data = []
for key,values in populations.items():
  values = values.to_dict(orient='records')
  for value in values:
    value["country"] = key
    value["ucdp_year"] = 2020
    json_data.append( value )
print(json_data)

file_path = 'ucdp_v241_y2020_gpw_population.json'
with open(file_path, 'w') as json_file:
    json.dump(json_data, json_file, indent=4)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [{'start_date': '2000-01-01', 'population_value': 26366300.903961167, 'country': 'Afghanistan', 'ucdp_year': 2020}, {'start_date': '2005-01-01', 'population_value': 28950109.06453464, 'country': 'Afghanistan', 'ucdp_year': 2020}, {'start_date': '2010-01-01', 'population_value': 31984663.797627393, 'country': 'Afghanistan', 'ucdp_year': 2020}, {'start_date': '2015-01-01', 'population_value': 35524931.17071788, 'country': 'Afghanistan', 'ucdp_year': 2020}, {'start_date': '2020-01-01', 'population_value': 39638138.538149714, 'country': 'Afghanistan', 'ucdp_year': 2020}, {'start_date': '2000-01-01', 'population_value': 4986110.143347442, 'country': 'Algeria', 'ucdp_year': 2020}, {'start_date': '2005-01-01', 'population_value': 5308791.936064149, 'country': 'Algeria', 'ucdp_year': 2020}, {'start_date': '2010-01-01', 'population_value': 5678474.241867955, 'country': 'Algeria', 'ucdp_year': 2020}, {'start_date': '2015-01-01', 'population_value': 6107710.894165489, 'country': 'Algeria', 'ucdp_year': 2020}, {'start_date': '2020-01-01', 'population_value': 6637067.64486855, 'country': 'Algeria', 'ucdp_year': 2020}, {'start_date': '2000-01-01', 'population_value': 2458948.1383077945, 'country': 'Angola', 'ucdp_year': 2020}, {'start_date': '2005-01-01', 'population_value': 3168878.8067304953, 'country': 'Angola', 'ucdp_year': 2020}, {'start_date': '2010-01-01', 'population_value': 5027755.373443597, 'country': 'Angola', 'ucdp_year': 2020}, {'start_date': '2015-01-01', 'population_value': 9335634.07711337, 'country': 'Angola', 'ucdp_year': 2020}, {'start_date': '2020-01-01', 'population_value': 18970190.21669906, 'country': 'Angola', 'ucdp_year': 2020}, {'start_date': '2000-01-01', 'population_value': 2436089.4451926993, 'country': 'Armenia', 'ucdp_year': 2020}, {'start_date': '2005-01-01', 'population_value': 2297297.5015567713, 'country': 'Armenia', 'ucdp_year': 2020}, {'start_date': '2010-01-01', 'population_value': 2230193.0295628486, 'country': 'Armenia', 'ucdp_year': 2020}, {'start_date': '2015-01-01', 'population_value': 2201599.642552992, 'country': 'Armenia', 'ucdp_year': 2020}, {'start_date': '2020-01-01', 'population_value': 2194838.6878017797, 'country': 'Armenia', 'ucdp_year': 2020}, {'start_date': '2000-01-01', 'population_value': 2441949.3719323366, 'country': 'Austria', 'ucdp_year': 2020}, {'start_date': '2005-01-01', 'population_value': 2554790.2915351847, 'country': 'Austria', 'ucdp_year': 2020}, {'start_date': '2010-01-01', 'population_value': 2674238.4969093613, 'country': 'Austria', 'ucdp_year': 2020}, {'start_date': '2015-01-01', 'population_value': 2800742.142540672, 'country': 'Austria', 'ucdp_year': 2020}, {'start_date': '2020-01-01', 'population_value': 2934790.395165072, 'country': 'Austria', 'ucdp_year': 2020}, {'start_date': '2000-01-01', 'population_value': 4326106.673610293, 'country': 'Azerbaijan', 'ucdp_year': 2020}, {'start_date': '2005-01-01', 'population_value': 4380648.35594388, 'country': 'Azerbaijan', 'ucdp_year': 2020}, {'start_date': '2010-01-01', 'population_value': 4462068.035792849, 'country': 'Azerbaijan', 'ucdp_year': 2020}, {'start_date': '2015-01-01', 'population_value': 4563991.803207573, 'country': 'Azerbaijan', 'ucdp_year': 2020}, {'start_date': '2020-01-01', 'population_value': 4682989.5082157375, 'country': 'Azerbaijan', 'ucdp_year': 2020}, {'start_date': '2000-01-01', 'population_value': 27525503.71795167, 'country': 'Bangladesh', 'ucdp_year': 2020}, {'start_date': '2005-01-01', 'population_value': 31124927.02208782, 'country': 'Bangladesh', 'ucdp_year': 2020}, {'start_date': '2010-01-01', 'population_value': 35335205.814306825, 'country': 'Bangladesh', 'ucdp_year': 2020}, {'start_date': '2015-01-01', 'population_value': 40278091.039673604, 'country': 'Bangladesh', 'ucdp_year': 2020}, {'start_date': '2020-01-01', 'population_value': 46102591.131509386, 'country': 'Bangladesh', 'ucdp_year': 2020}, {'start_date': '2000-01-01', 'population_value': 194606.3501055876, 'country': 'Benin', 'uc ...

# %%
json_data = pd.DataFrame(json_data)
json_data.sort_values(by='population_value', ascending=False, inplace=True)

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 15))
sns.barplot(data=json_data, x='population_value', y='country', hue='start_date', palette='Set1')

country_mean = json_data.groupby('country')['population_value'].mean().reset_index()
sns.scatterplot(data=country_mean, x='population_value', y='country', color='black', marker='X', s=25, label='Mean')

plt.xscale('log')
plt.xlabel('Population Value (log scale)')
plt.ylabel('Country')
plt.title('Population Value per Country and Start Date')

plt.grid(axis='x', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)

plt.savefig('ucdp_v241_y2020_gpw_population.png', bbox_inches='tight')
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
